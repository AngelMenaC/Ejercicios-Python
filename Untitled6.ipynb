# %% [markdown]
# <a href="https://colab.research.google.com/github/AngelMenaC/Ejercicios-Python/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
EdJuan= 9
EdAlber= 2/3 * EdJuan
EdAna= 4/3 * EdJuan
EdMama=EdJuan+EdAlber+EdAna
print(EdJuan)
print(EdAlber)
print(EdAna)
print(EdMama)
# Out:
# 9
# 6.0
# 12.0
# 27.0

# %%
Horas_De_Trabajo= 48
Pago_Hora= 5.000
